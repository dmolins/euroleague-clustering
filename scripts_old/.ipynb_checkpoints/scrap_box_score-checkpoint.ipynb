# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import pandas as pd

first_time = True

year = 18
url = 'https://www.basketball-reference.com/international/euroleague/20{}.html'.format(year)

df = pd.DataFrame(columns=header) #aixo esta malament oju!!! no esta definit header

#opening up connection, grabbing the page
uClient = uReq(url)
page_html = uClient.read()
uClient.close()

#html parser
page_soup = soup(page_html, "html.parser")

container = page_soup.find("table")
teams_html = container.tbody.find_all('tr')

(teams, links) = get_links(teams_html)

#agafar stats d'un equip
for i in range(len(teams)):
    df_add, header = get_season_stats('https://www.basketball-reference.com' + links[i], first_time, teams[i], year)
    df_concat = [df, df_add]
    df = pd.concat(df_concat)

df.to_csv('/Users/dmolins/Desktop/david/uni/TFG/season-stats/Euroleague_box-score_{}.csv'.format(year), 
          sep=';', header = header, index = False)

# %%
def get_links(teams):
    team_names = []
    links = []
    for t in teams:
        team_names.append(t.find("a").text)
        links.append(t.find("a")['href'])
    return (team_names, links)

# %%
def get_euroleague_table(container):
    for table in container:
        if table.get('id') == 'player_per_game-elg':
            return table

# %%
def get_header(table):
    header = []
    header_html = table.thead.find_all('th')
    for line in header_html:
        header.append(line.text)
    header.append('Team') 
    header.append('Season')
    return header

# %%
def get_season_stats(url, first_time, team, year):
    #opening up connection, grabbing the page
    uClient2 = uReq(url)
    page_html2 = uClient2.read()
    uClient2.close()
    
    #html parser
    page_soup = soup(page_html2, "html.parser")
    container = page_soup.findAll("table")
    
    table = get_euroleague_table(container)
    
    if(first_time):
        header = get_header(table)
        first_time = False
    
    l = []
    for tr in table.tbody.find_all('tr'):
        th = tr.find_all('th')
        td = tr.find_all('td')
        row = [th[0].text]

        for tr in td:
            row.append(tr.text)
        row.append(team)
        row.append(year)
        l.append(row)
    
    df_add = pd.DataFrame(l, columns=header)
    
    return df_add, header

# %%
    year = 19
    
    url = 'https://www.basketball-reference.com/international/euroleague/20{}.html'.format(year)
    
    df = pd.DataFrame(columns=header)
    
    #opening up connection, grabbing the page
    uClient = uReq(url)
    page_html = uClient.read()
    uClient.close()
    
    #html parser
    page_soup = soup(page_html, "html.parser")
    
    container = page_soup.find("table")
    teams_html = container.tbody.find_all('tr')
    
    (teams, links) = get_links(teams_html)
    
    #agafar stats d'un equip
    for i in range(len(teams)):
        df_add, header = get_season_stats('https://www.basketball-reference.com' + links[i], first_time, teams[i], year)
        df_concat = [df, df_add]
        #df.append(df_add, ignore_index=True)
        #print(teams[i])
        #print(df_add)
        df = pd.concat(df_concat)
        
    df
# Out:
#               Player   G    MP   FG   FGA   FG%   3P  3PA   3P%   2P  ...  \
# 0         Kyle Hines  36  19.6  2.9   5.0  .580  0.0  0.0        2.9  ...
# 1     Othello Hunter  36  17.9  3.3   5.5  .596  0.0  0.0        3.3  ...
# 2        Alec Peters  36  16.3  1.8   4.2  .420  1.1  2.5  .433  0.7  ...
# 3       Will Clyburn  35  27.0  4.6   9.8  .474  1.0  2.8  .343  3.7  ...
# 4   Sergio Rodriguez  35  21.9  3.6   8.6  .421  1.9  4.9  .392  1.7  ...
# ..               ...  ..   ...  ...   ...   ...  ...  ...   ...  ...  ...
# 10     Toney Douglas  20  27.6  5.2  12.6  .410  1.9  5.6  .330  3.3  ...
# 11      Markel Brown  20  17.5  1.7   4.9  .347  0.7  2.7  .259  1.0  ...
# 12      Ray McCallum  16  22.1  3.8   9.7  .394  0.6  2.2  .286  3.2  ...
# 13     Emircan Kosut  15   8.2  1.3   2.7  .500  0.0  0.2  .000  1.3  ...
# 14         Mert Akay   7  11.0  1.0   2.4  .412  0.3  1.1  .250  0.7  ...
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS                Team Season
# 0   1.8  3.6  1.4  0.7  0.7  1.0  2.6   7.3         CSKA Moscow     19
# 1   2.4  4.3  0.9  0.5  0.4  0.8  2.3   7.7         CSKA Moscow     19
# 2   2.0  2.7  0.7  0.5  0.1  0.6  2.4   5.3         CSKA Moscow     19
# 3   5.1  6.8  1.5  1.0  0.2  1.4  1.9  13.6         CSKA Moscow     19
# 4   1.3  1.5  4.5  0.7  0.1  2.2  2.1  10.2         CSKA Moscow     19
# ..  ...  ...  ...  ...  ...  ...  ...   ...                 ...    ...
# 10  2.4  3.3  4.0  1.7  0.2  2.3  2.8  14.5  Darussafaka Tekfen     19
# 11  1.1  1.7  1.9  0.4  0.2  0.8  1.3   4.9  Darussafaka Tekfen     19
# 12  2.8  3.7  4.1  0.9  0.2  2.3  1.8   9.4  Darussafaka Tekfen     19
# 13  0.7  1.2  0.5  0.3  0.3  0.7  1.5   3.2  Darussafaka Tekfen     19
# 14  0.7  1.1  1.6  0.4  0.0  1.1  2.4   3.0  Darussafaka Tekfen     19
#
# [251 rows x 26 columns]
